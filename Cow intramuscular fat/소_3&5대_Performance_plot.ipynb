# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %% [markdown]
# ##### 3대 target_7,8,9

# %%
# create data
cutoff = [0.5, 0.6, 0.7, 0.8, 0.9]
npv = [0.7272, 0.7257, 0.7173, 0.7146, 0.7125]
ppv = [0.5748, 0.6586, 0.73, 0.8118, 0.9677]
spec = [0.9345, 0.9827, 0.9954, 0.9986, 1]
sens = [0.2187, 0.824, 0.307, 0.145, 0.0031]
auc = [0.7283, 0.7233, 0.7174, 0.7151, 0.7127]

# plot lines
plt.title('3대 Target_event = 1:(7, 8, 9), senspec')
plt.plot(cutoff, sens, label = "Sensitivity")
plt.plot(cutoff, spec, label = "Specificity")
plt.plot(cutoff, ppv, label = "PPV")
plt.plot(cutoff, npv, label = "NPV")
plt.plot(cutoff, auc, label = "Accuracy")
plt.ylabel('Cut-off')
plt.xlabel('Performance')
plt.legend()
plt.show()

# %%
# create data
cutoff = [0.5, 0.6, 0.7, 0.8]
sens = [0.922, 0.921, 0.921, 0.921]
spec = [0.472, 0.5, 0.429, 0]
ppv = [0.999, 1, 1, 1]
npv = [0.013, 0.006, 0.001, 0]
  
# plot lines
plt.title('3대 Target_event = 1:(9), senspec')
plt.plot(cutoff, sens, label = "Sensitivity")
plt.plot(cutoff, spec, label = "Specificity")
plt.plot(cutoff, ppv, label = "PPV")
plt.plot(cutoff, npv, label = "NPV")
plt.ylabel('Cut-off')
plt.xlabel('Performance')
plt.legend()
plt.show()

# %%
# create data
cutoff = [0.5, 0.6, 0.7, 0.8, 0.9]
sens = [0.7262, 0.702, 0.6924, 0.691, 0.6873]
spec = [0.6333, 0.74, 0.8333, 0.8571, 0.7143]
ppv = [0.939, 0.9856, 0.9967, 0.9978, 0.9978]
npv = [0.2295, 0.0894, 0.0362, 0.029, 0.0121]
  
# plot lines
plt.title('5대 Target_event = 1:(7, 8, 9), senspec')
plt.plot(cutoff, sens, label = "Sensitivity")
plt.plot(cutoff, spec, label = "Specificity")
plt.plot(cutoff, ppv, label = "PPV")
plt.plot(cutoff, npv, label = "NPV")
plt.ylabel('Cut-off')
plt.xlabel('Performance')
plt.legend()
plt.show()

# %%
# create data
cutoff = [0.5, 0.6]
sens = [0.904, 0.904]
spec = [0.286, 0.4]
ppv = [0.996, 0.998]
npv = [0.016, 0.016]
  
# plot lines
plt.title('5대 Target_event = 1:(9), senspec')
plt.plot(cutoff, sens, label = "Sensitivity")
plt.plot(cutoff, spec, label = "Specificity")
plt.plot(cutoff, ppv, label = "PPV")
plt.plot(cutoff, npv, label = "NPV")
plt.ylabel('Cut-off')
plt.xlabel('Performance')
plt.legend()
plt.show()

# %%
print(f'n0+:{23122+407}')
print(f'n1+:{8739+785}')
print(f'n+1:{23122+8739}')
print(f'n+0:{407+785}')
# Out:
# n0+:23529
# n1+:9524
# n+1:31861
# n+0:1192
