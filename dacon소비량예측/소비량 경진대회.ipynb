# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
import matplotlib.font_manager as fm
os.getcwd()
# Out:
# '/Users/idogeon/python3'

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 파일이 잘 불러졌나 확인

# %%
d_f=pd.read_csv('train123.csv')
d_f
# Out:
#         id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0        0        1974      Master       Together  46014.0        1         1
# 1        1        1962  Graduation         Single  76624.0        0         1
# 2        2        1951  Graduation        Married  75903.0        0         1
# 3        3        1974       Basic        Married  18393.0        1         0
# 4        4        1946         PhD       Together  64014.0        2         1
# ...    ...         ...         ...            ...      ...      ...       ...
# 1103  1103        1956  Graduation       Together  46097.0        0         1
# 1104  1104        1986  Graduation        Married  23477.0        1         0
# 1105  1105        1975      Master        Married  37368.0        1         0
# 1106  1106        1974  Graduation       Divorced  53034.0        1         1
# 1107  1107        1952         PhD       Divorced  46610.0        0         2
#
# ...

# %% [markdown]
# ### 데이터 확인

# %%
d_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1108 entries, 0 to 1107
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1108 non-null   int64
#  1   Year_Birth           1108 non-null   int64
#  2   Education            1108 non-null   object
#  3   Marital_Status       1108 non-null   object
#  4   Income               1108 non-null   float64
#  5   Kidhome              1108 non-null   int64
#  6   Teenhome             1108 non-null   int64
#  7   Dt_Customer          1108 non-null   object
#  8   Recency              1108 non-null   int64
#  9   NumDealsPurchases    1108 non-null   int64
#  10  NumWebPurchases      1108 non-null   int64
#  11  NumCatalogPurchases  1108 non-null   int64
#  12  NumStorePurchases    1108 non-null   int64
#  13  NumWebVisitsMonth    1108 non-null   int64
#  14  AcceptedCmp3         1108 non-null   int64
# ...

# %%
print(d_f.describe())
print(d_f.describe(include = object))
# Out:
#                 id   Year_Birth         Income      Kidhome     Teenhome  \
# count  1108.000000  1108.000000    1108.000000  1108.000000  1108.000000
# mean    553.500000  1968.701264   52075.809567     0.429603     0.511733
# std     319.996354    12.225380   21310.093395     0.545582     0.551624
# min       0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     276.750000  1959.000000   35768.500000     0.000000     0.000000
# 50%     553.500000  1970.000000   51609.500000     0.000000     0.000000
# 75%     830.250000  1977.000000   68325.000000     1.000000     1.000000
# max    1107.000000  1996.000000  162397.000000     2.000000     2.000000
#
#            Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  1108.000000         1108.00000      1108.000000          1108.000000
# mean     50.156137            2.33935         4.184116             2.690433
# std      29.085582            1.94328         2.810556             2.792236
# ...

# %% [markdown]
# ### 결측치 없음확인

# %%
d_f.isnull().sum()
# Out:
# id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Response               0
# target                 0
# dtype: int64

# %% [markdown]
# # 시각화

# %%
plt.hist(d_f['target'], bins=10)
# Out:
# (array([466., 144.,  93., 105., 105.,  79.,  57.,  38.,  17.,   4.]),
#  array([   6. ,  257.9,  509.8,  761.7, 1013.6, 1265.5, 1517.4, 1769.3,
#         2021.2, 2273.1, 2525. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(d_f1['NumDealsPurchases'])
plt.show()
# Out:
# /Users/idogeon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(d_f1['target'])
# Out:
# /Users/idogeon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='target', ylabel='Density'>

# %%
plt.boxplot(x='Income',data=d_f)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7c441dca0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7e5940400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7c441d910>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7e5940b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7e5940eb0>],
#  'means': []}

# %%
sns.distplot(d_f1['NumWebPurchases'])
# Out:
# /Users/idogeon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NumWebPurchases', ylabel='Density'>

# %%
sns.distplot(d_f1['NumCatalogPurchases'])
# Out:
# /Users/idogeon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NumCatalogPurchases', ylabel='Density'>

# %%
sns.countplot(x='NumWebVisitsMonth',data=d_f)
# Out:
# <AxesSubplot:xlabel='NumWebVisitsMonth', ylabel='count'>

# %%
sns.distplot(d_f1['NumStorePurchases'])
# Out:
# /Users/idogeon/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NumStorePurchases', ylabel='Density'>

# %%
plt.boxplot(x='target',data=d_f)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7d1e59220>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7d1e59940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7d1e345b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7d1e660a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7d1e66430>],
#  'means': []}

# %%
plt.boxplot(x='Year_Birth',data=d_f)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7b2265b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7b2272280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7b2265790>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7b22729a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7b2272d30>],
#  'means': []}

# %% [markdown]
# ### 나이가 많으신 분들은 소비량이 적다.

# %%
d_f[(d_f['Year_Birth']<1920)]
# Out:
#       id  Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# 760  760        1900  2n Cycle       Divorced  36640.0        1         0
# 865  865        1893  2n Cycle         Single  60182.0        0         1
#
#     Dt_Customer  Recency  NumDealsPurchases  ...  NumStorePurchases  \
# 760  26-09-2013       99                  1  ...                  2
# 865  17-05-2014       23                  1  ...                  2
#
#      NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 760                  5             0             0             0
# 865                  4             0             0             0
#
#      AcceptedCmp1  AcceptedCmp2  Complain  Response  target
# 760             0             0         1         0      65
# 865             0             0         0         0      22
#
# [2 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(d_f['Income'],d_f['NumDealsPurchases'],alpha=0.2,color='red')
plt.xlabel='소득'
plt.ylabel='구매액'
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(d_f['Income'],d_f['target'],alpha=0.2,color='red')
plt.xlabel='소득'
plt.ylabel='구매액'
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(d_f['NumCatalogPurchases'],d_f['target'],alpha=0.2,color='red')
plt.show()

# %% [markdown]
# ### 카탈로그는 상품을 구매할 것이 예상되는 손님에게 구입상 참고가 될 만한 사항을 나타내 보이는 것. (특징,가격,사진 등)
# ### 소비량과 카탈로그의 구매수를 상관계수가 높은 것을 볼 수 있는데 참고가 될 만한 것들이 있을수록 더 많이 구매하는 것으로 생각할 수 있다.
#
# ## 소비량과 매장에서 직접 구매한 수도 상관계수가 높은데 매장에서 직접 제품을 보는 것은 카탈로그가 제공되는 것이기 때문에 카탈로그를 만들어 주는게 좋다.

# %%
d_f[['target','NumCatalogPurchases']].corr()  #종속변수와 독립변수 상관계수 돌리는게 맞나..? 모르겠음.
# Out:
#                        target  NumCatalogPurchases
# target               1.000000             0.798065
# NumCatalogPurchases  0.798065             1.000000

# %%
d_f[['Income','NumCatalogPurchases']].corr()
# Out:
#                       Income  NumCatalogPurchases
# Income               1.00000              0.68621
# NumCatalogPurchases  0.68621              1.00000

# %%
d_f[['Income','target']].corr()
# Out:
#           Income    target
# Income  1.000000  0.784084
# target  0.784084  1.000000

# %%
d_f[['target','NumStorePurchases']].corr()
# Out:
#                      target  NumStorePurchases
# target             1.000000           0.677785
# NumStorePurchases  0.677785           1.000000

# %%
plt.boxplot(x='NumWebVisitsMonth',data=d_f)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7e5b476a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7e5b47d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7e5b47310>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7e5b53370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7e5b53700>],
#  'means': []}

# %%
plt.boxplot(x='Income',data=d_f)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7e5c1a130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7e5c1a850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7e5c0ad60>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7e5c1af70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7e5c26340>],
#  'means': []}

# %%
d_f[(d_f['Income']>120000)]
# Out:
#       id  Year_Birth   Education Marital_Status    Income  Kidhome  Teenhome  \
# 246  246        1976         PhD       Together  162397.0        1         1
# 686  686        1975  Graduation       Divorced  153924.0        0         0
# 730  730        1971      Master       Together  157733.0        1         0
#
#     Dt_Customer  Recency  NumDealsPurchases  ...  NumStorePurchases  \
# 246  03-06-2013       31                  0  ...                  1
# 686  07-02-2014       81                  0  ...                  0
# 730  04-06-2013       37                  0  ...                  1
#
#      NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 246                  1             0             0             0
# 686                  0             0             0             0
# 730                  1             0             0             0
#
#      AcceptedCmp1  AcceptedCmp2  Complain  Response  target
# ...

# %%
d_f.drop([246,686,730])
# Out:
#         id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0        0        1974      Master       Together  46014.0        1         1
# 1        1        1962  Graduation         Single  76624.0        0         1
# 2        2        1951  Graduation        Married  75903.0        0         1
# 3        3        1974       Basic        Married  18393.0        1         0
# 4        4        1946         PhD       Together  64014.0        2         1
# ...    ...         ...         ...            ...      ...      ...       ...
# 1103  1103        1956  Graduation       Together  46097.0        0         1
# 1104  1104        1986  Graduation        Married  23477.0        1         0
# 1105  1105        1975      Master        Married  37368.0        1         0
# 1106  1106        1974  Graduation       Divorced  53034.0        1         1
# 1107  1107        1952         PhD       Divorced  46610.0        0         2
#
# ...

# %%
d_f[['NumWebVisitsMonth','NumWebPurchases']].corr()
# Out:
#                    NumWebVisitsMonth  NumWebPurchases
# NumWebVisitsMonth           1.000000        -0.085937
# NumWebPurchases            -0.085937         1.000000

# %% [markdown]
# ### 웹 방문 횟수가 높다고 웹 구매횟수 높은거 아니다. 즉, 소비량 높은거 아니다.

# %%
d_f[['target','NumWebPurchases']].corr()
# Out:
#                    target  NumWebPurchases
# target           1.000000         0.546082
# NumWebPurchases  0.546082         1.000000

# %%
d_f[(d_f['NumWebVisitsMonth']>12)]['NumWebPurchases']
# Out:
# 91      0
# 182     0
# 194     1
# 297     0
# 1097    0
# Name: NumWebPurchases, dtype: int64

# %%
d_f[['NumWebVisitsMonth','NumWebPurchases']].corr()
# Out:
#                    NumWebVisitsMonth  NumWebPurchases
# NumWebVisitsMonth           1.000000        -0.085937
# NumWebPurchases            -0.085937         1.000000

# %%
pear_r,pear_pval = stats.spearmanr(d_f['NumWebVisitsMonth'],d_f['NumWebPurchases'])
print(f'상관계수:{pear_r},유의확률:{pear_pval}')
# Out:
# 상관계수:-0.12802923186471377,유의확률:1.9160641272332076e-05

# %%
dff1=d_f[(d_f['NumWebVisitsMonth']>6)]
print(dff1.describe())
print(dff1.describe(include = object))
# Out:
#                 id   Year_Birth        Income     Kidhome    Teenhome  \
# count   405.000000   405.000000    405.000000  405.000000  405.000000
# mean    566.528395  1970.412346  38515.644444    0.688889    0.493827
# std     331.689020    11.208658  15680.333623    0.542272    0.547801
# min       0.000000  1944.000000   1730.000000    0.000000    0.000000
# 25%     292.000000  1964.000000  27450.000000    0.000000    0.000000
# 50%     583.000000  1971.000000  37244.000000    1.000000    0.000000
# 75%     860.000000  1978.000000  49090.000000    1.000000    1.000000
# max    1106.000000  1996.000000  94871.000000    2.000000    2.000000
#
#           Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  405.000000         405.000000       405.000000           405.000000
# mean    48.935802           2.948148         3.753086             1.254321
# std     28.261085           2.361988         2.797324             1.759560
# ...

# %%
d_f[(d_f['NumWebVisitsMonth']>10)]
# Out:
#         id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 91      91        1963         PhD        Married  4023.0        1         1
# 182    182        1971  Graduation       Divorced  1730.0        0         0
# 194    194        1976  Graduation        Married  5305.0        0         1
# 297    297        1957         PhD       Together  6835.0        0         1
# 1097  1097        1965  Graduation       Divorced  4861.0        0         0
#
#      Dt_Customer  Recency  NumDealsPurchases  ...  NumStorePurchases  \
# 91    23-06-2014       29                 15  ...                  0
# 182   18-05-2014       65                 15  ...                  0
# 194   30-07-2013       12                  0  ...                  0
# 297   08-12-2012       76                  0  ...                  1
# 1097  22-06-2014       20                  0  ...                  0
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# ...

# %% [markdown]
# ### 애기들이 있어서 바쁘면 웹사이트에서 더 사지않을까?

# %%
import matplotlib.pyplot as plt
plt.scatter(d_f['Kidhome'],d_f['NumWebPurchases'],alpha=0.2,color='red')
plt.xlabel='자녀'
plt.ylabel='웹구매'
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(d_f['NumCatalogPurchases'],d_f['target'],alpha=0.2,color='red')
plt.xlabel='자녀'
plt.ylabel='웹구매'
plt.show()

# %%
d_f['Education'].unique()
# Out:
# array(['Master', 'Graduation', 'Basic', 'PhD', '2n Cycle'], dtype=object)

# %%
d_f['Year_Birth'].unique()
# Out:
# array([1974, 1962, 1951, 1946, 1952, 1971, 1978, 1968, 1966, 1982, 1949,
#        1977, 1969, 1960, 1947, 1961, 1976, 1953, 1975, 1970, 1988, 1986,
#        1983, 1956, 1973, 1979, 1944, 1972, 1965, 1985, 1959, 1964, 1954,
#        1950, 1989, 1955, 1980, 1984, 1963, 1958, 1967, 1987, 1948, 1991,
#        1957, 1941, 1993, 1990, 1992, 1945, 1981, 1943, 1995, 1996, 1900,
#        1893, 1940])

# %%
d_f['Marital_Status'].unique()
# Out:
# array(['Together', 'Single', 'Married', 'Widow', 'Divorced', 'Alone',
#        'YOLO', 'Absurd'], dtype=object)

# %% [markdown]
# ## 새로운 파생변수 Dependents. 자녀의 수를 나이에 상관없이 합침.

# %%
d_f['Dependents'] = d_f['Kidhome'] + d_f['Teenhome']
d_f['Dependents']
# Out:
# 0       2
# 1       1
# 2       1
# 3       1
# 4       3
#        ..
# 1103    1
# 1104    1
# 1105    1
# 1106    2
# 1107    2
# Name: Dependents, Length: 1108, dtype: int64

# %%
plt.boxplot(x='Dependents',data=d_f)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7c4076160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7c40760a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7c40761f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7c41405e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7c4140400>],
#  'means': []}

# %%
d_f[['Dependents','Income']].corr()
# Out:
#             Dependents    Income
# Dependents    1.000000 -0.315339
# Income       -0.315339  1.000000

# %%
d_f[['Dependents','target']].corr()
# Out:
#             Dependents    target
# Dependents    1.000000 -0.471012
# target       -0.471012  1.000000

# %% [markdown]
# ### 고객의 결혼 상태를 Single과 Together 두가지로 나눈 Marital_Status_Group라는 새변수 생성

# %%
d_f['Marital_Status'].unique()
# Out:
# array(['Together', 'Single', 'Married', 'Widow', 'Divorced', 'Alone',
#        'YOLO', 'Absurd'], dtype=object)

# %%
d_f[(d_f['Marital_Status'] == "Alone")]
# Out:
#       id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 272  272        1973         PhD          Alone  35860.0        1         1
# 606  606        1988  Graduation          Alone  34176.0        1         0
#
#     Dt_Customer  Recency  NumDealsPurchases  ...  NumWebVisitsMonth  \
# 272  19-05-2014       37                  2  ...                  5
# 606  12-05-2014       12                  4  ...                  6
#
#      AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# 272             1             0             0             0             0
# 606             0             0             0             0             0
#
#      Complain  Response  target  Dependents
# 272         0         1      49           2
# 606         0         0      89           1
#
# [2 rows x 23 columns]

# %%
d_f[(d_f['Marital_Status'] == "YOLO")]
# Out:
#       id  Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# 292  292        1973       PhD           YOLO  48432.0        0         1
#
#     Dt_Customer  Recency  NumDealsPurchases  ...  NumWebVisitsMonth  \
# 292  18-10-2012        3                  5  ...                  8
#
#      AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# 292             0             0             0             0             0
#
#      Complain  Response  target  Dependents
# 292         0         0     424           1
#
# [1 rows x 23 columns]

# %%
d_f['Marital_Status_Group'] = d_f['Marital_Status'] 
d_f['Marital_Status_Group']
# Out:
# 0       Together
# 1         Single
# 2        Married
# 3        Married
# 4       Together
#           ...
# 1103    Together
# 1104     Married
# 1105     Married
# 1106    Divorced
# 1107    Divorced
# Name: Marital_Status_Group, Length: 1108, dtype: object

# %% [markdown]
# ### 자녀의 수가 없고 Together과 Married가 아닌 사람은 싱글 , 그외는 Together

# %%
d_f.loc[(d_f.Dependents ==0) & (d_f.Marital_Status != 'Together') & (d_f.Marital_Status != 'Married'), 'Marital_Status_Group'] = 'Single'

# %%
d_f.loc[(d_f.Dependents >0) | (d_f.Marital_Status =='Together') | (d_f.Marital_Status == 'Married'), 'Marital_Status_Group'] = 'Together'

# %%
d_f['Marital_Status_Group']
# Out:
# 0       Together
# 1       Together
# 2       Together
# 3       Together
# 4       Together
#           ...
# 1103    Together
# 1104    Together
# 1105    Together
# 1106    Together
# 1107    Together
# Name: Marital_Status_Group, Length: 1108, dtype: object

# %%
d_f[(d_f['Marital_Status_Group'] =='Together')]
# Out:
#         id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0        0        1974      Master       Together  46014.0        1         1
# 1        1        1962  Graduation         Single  76624.0        0         1
# 2        2        1951  Graduation        Married  75903.0        0         1
# 3        3        1974       Basic        Married  18393.0        1         0
# 4        4        1946         PhD       Together  64014.0        2         1
# ...    ...         ...         ...            ...      ...      ...       ...
# 1103  1103        1956  Graduation       Together  46097.0        0         1
# 1104  1104        1986  Graduation        Married  23477.0        1         0
# 1105  1105        1975      Master        Married  37368.0        1         0
# 1106  1106        1974  Graduation       Divorced  53034.0        1         1
# 1107  1107        1952         PhD       Divorced  46610.0        0         2
#
# ...

# %%
d_f[(d_f['Marital_Status_Group'] =='Single')]
# Out:
#         id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 18      18        1947      Master         Single  91712.0        0         0
# 32      32        1974  Graduation         Single  69719.0        0         0
# 38      38        1944         PhD       Divorced  55614.0        0         0
# 50      50        1954  Graduation         Single  22507.0        0         0
# 67      67        1976      Master       Divorced  75012.0        0         0
# ...    ...         ...         ...            ...      ...      ...       ...
# 1086  1086        1956      Master         Single  64857.0        0         0
# 1087  1087        1976      Master         Single  72309.0        0         0
# 1092  1092        1987         PhD         Single  74004.0        0         0
# 1097  1097        1965  Graduation       Divorced   4861.0        0         0
# 1102  1102        1946         PhD         Single  82800.0        0         0
#
# ...

# %% [markdown]
# ## d_f1은 d_f에서 생년 이상치와 웹 방문횟수 변수 삭제. 새로운 파생 변수 Dependents, Marital_Status_Group 추가.
# ## 구매의 합을 값으로하는 새로운 변수 TotalPurchases, 캠페인 참여 횟수의 합을 값으로 하는 새로운 변수 TotalAcceptedCmp 추가.

# %%
d_f00 = d_f.drop([760,865], axis = 0)

# %%
d_f1=d_f00.drop(['NumWebVisitsMonth'],axis=1)

# %%
d_f1['TotalPurchases'] = d_f1['NumDealsPurchases'] + d_f1['NumWebPurchases']+ d_f1['NumStorePurchases']+ d_f1['NumWebPurchases']+d_f1['NumCatalogPurchases'] 
d_f1['TotalPurchases']
# Out:
# 0       33
# 1       28
# 2       29
# 3       11
# 4       30
#         ..
# 1103    18
# 1104    13
# 1105     5
# 1106    28
# 1107    21
# Name: TotalPurchases, Length: 1106, dtype: int64

# %% [markdown]
# ### 캠페인 2는 한 사람이 너무 적어서 캠페인참여 횟수 합에 포함 x

# %%
d_f1['TotalAcceptedCmp'] = d_f1['AcceptedCmp1'] + d_f1['AcceptedCmp3']+ d_f1['AcceptedCmp5']+ d_f1['Response']
d_f1['TotalAcceptedCmp']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 1103    0
# 1104    0
# 1105    1
# 1106    0
# 1107    1
# Name: TotalAcceptedCmp, Length: 1106, dtype: int64

# %%
d_f1
# Out:
#         id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0        0        1974      Master       Together  46014.0        1         1
# 1        1        1962  Graduation         Single  76624.0        0         1
# 2        2        1951  Graduation        Married  75903.0        0         1
# 3        3        1974       Basic        Married  18393.0        1         0
# 4        4        1946         PhD       Together  64014.0        2         1
# ...    ...         ...         ...            ...      ...      ...       ...
# 1103  1103        1956  Graduation       Together  46097.0        0         1
# 1104  1104        1986  Graduation        Married  23477.0        1         0
# 1105  1105        1975      Master        Married  37368.0        1         0
# 1106  1106        1974  Graduation       Divorced  53034.0        1         1
# 1107  1107        1952         PhD       Divorced  46610.0        0         2
#
# ...

# %%
plt.boxplot(x='Year_Birth',data=d_f1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7e55b6160>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7e55ae2b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7e55b66a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7e55aea30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7e55c6040>],
#  'means': []}

# %%
print(d_f1[['Income','NumCatalogPurchases']].corr())
print(d_f1[['target','NumCatalogPurchases']].corr()) 
print(d_f1[['Income','target']].corr() )
print(d_f1[['target','NumStorePurchases']].corr())
# Out:
#                        Income  NumCatalogPurchases
# Income               1.000000             0.686754
# NumCatalogPurchases  0.686754             1.000000
#                        target  NumCatalogPurchases
# target               1.000000             0.797825
# NumCatalogPurchases  0.797825             1.000000
#           Income    target
# Income  1.000000  0.784704
# target  0.784704  1.000000
#                      target  NumStorePurchases
# target             1.000000           0.677162
# NumStorePurchases  0.677162           1.000000

# %% [markdown]
# ### 상관계수가 통계적으로 유의하다.

# %%
import scipy.stats as stats

# %%
pear_r,pear_pval = stats.pearsonr(d_f['Income'],d_f['target'])
print(f'상관계수:{pear_r},유의확률:{pear_pval}')
# Out:
# 상관계수:0.7840842864808519,유의확률:2.383663997291235e-231

# %%
pear_r,pear_pval = stats.pearsonr(d_f1['NumStorePurchases'],d_f1['target'])
print(f'상관계수:{pear_r},유의확률:{pear_pval}')
# Out:
# 상관계수:0.6771622616198265,유의확률:2.9783695104076086e-149

# %%
pear_r,pear_pval = stats.pearsonr(d_f1['NumCatalogPurchases'],d_f1['Income'])
print(f'상관계수:{pear_r},유의확률:{pear_pval}')
# Out:
# 상관계수:0.686754264354624,유의확률:4.0209837280963815e-155

# %%
pear_r,pear_pval = stats.pearsonr(d_f1['Income'],d_f1['NumCatalogPurchases'])
print(f'상관계수:{pear_r},유의확률:{pear_pval}')
# Out:
# 상관계수:0.686754264354624,유의확률:4.0209837280963815e-155

# %% [markdown]
# ### 캠페인에 참여한 횟수가 많을수록 소비량이 많이크다. 그리고 마지막 캠페인을 다 참여함. 기준3으로 대부분 평균보다 많이 높은 수치라는 것을 알 수 있다.
# ### 또, 자식이 거의 없는 사람들이다.

# %%
d_f1[(d_f1['TotalAcceptedCmp']>2)]['target']
# Out:
# 16      1757
# 88      1479
# 94       523
# 115     2053
# 137     1862
# 174     2069
# 214     1135
# 243     2086
# 286     1941
# 303     1750
# 323     1690
# 348     1415
# 407     1957
# 422     2257
# 473      557
# 573     2302
# 633     1315
# 677     1216
# 712     1789
# 721     1092
# 799     1024
# 855     1808
# 869     1274
# 870     1792
# 983     1688
# 1035    1676
# 1092    1658
# 1102    1315
# Name: target, dtype: int64

# %%
d___f1=d_f1[(d_f1['TotalAcceptedCmp']<3)]
print(d___f1.describe())
print(d___f1.describe(include = object))
# Out:
#                id   Year_Birth         Income      Kidhome     Teenhome  \
# count  1078.00000  1078.000000    1078.000000  1078.000000  1078.000000
# mean    553.88590  1968.799629   51236.345083     0.438776     0.521336
# std     319.68551    11.782410   20896.960905     0.548027     0.551026
# min       0.00000  1940.000000    1730.000000     0.000000     0.000000
# 25%     277.25000  1959.000000   35265.000000     0.000000     0.000000
# 50%     553.50000  1970.000000   50827.500000     0.000000     0.000000
# 75%     829.75000  1977.000000   67299.750000     1.000000     1.000000
# max    1107.00000  1996.000000  162397.000000     2.000000     2.000000
#
#            Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  1078.000000        1078.000000      1078.000000          1078.000000
# mean     50.202226           2.377551         4.164193             2.577922
# std      29.034637           1.950487         2.823488             2.702685
# ...

# %%
d___f2=d_f1[(d_f1['TotalAcceptedCmp']>2)]
print(d___f2.describe())
print(d___f2.describe(include = object))
# Out:
#                 id   Year_Birth         Income    Kidhome   Teenhome  \
# count    28.000000    28.000000      28.000000  28.000000  28.000000
# mean    520.142857  1970.071429   84656.964286   0.071429   0.142857
# std     339.667126    14.173341    7738.401507   0.262265   0.448395
# min      16.000000  1946.000000   64140.000000   0.000000   0.000000
# 25%     235.750000  1957.500000   80904.750000   0.000000   0.000000
# 50%     447.500000  1975.000000   84662.500000   0.000000   0.000000
# 75%     813.000000  1980.250000   88815.000000   0.000000   0.000000
# max    1102.000000  1993.000000  101970.000000   1.000000   2.000000
#
#          Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  28.000000          28.000000        28.000000            28.000000
# mean   47.607143           0.964286         5.142857             7.178571
# std    30.587263           0.961563         2.085475             2.553916
# ...

# %%
print(d_f1.describe())
print(d_f1.describe(include = object))
# Out:
#                 id   Year_Birth         Income      Kidhome     Teenhome  \
# count  1106.000000  1106.000000    1106.000000  1106.000000  1106.000000
# mean    553.031646  1968.831826   52082.436709     0.429476     0.511754
# std     320.088082    11.842966   21322.919201     0.545653     0.551712
# min       0.000000  1940.000000    1730.000000     0.000000     0.000000
# 25%     276.250000  1959.000000   35723.500000     0.000000     0.000000
# 50%     552.500000  1970.000000   51609.500000     0.000000     0.000000
# 75%     829.750000  1977.000000   68343.000000     1.000000     1.000000
# max    1107.000000  1996.000000  162397.000000     2.000000     2.000000
#
#            Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  1106.000000        1106.000000      1106.000000          1106.000000
# mean     50.136528           2.341772         4.188969             2.694394
# std      29.063301           1.944201         2.810695             2.793124
# ...

# %% [markdown]
# ### 불만을 제기한 사람들은 소비량이 낮을까? 낮다.

# %%
d_f1[(d_f1['Complain']>0)]
# Out:
#         id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 448    448        1983      Master         Single  31788.0        1         0
# 545    545        1943      Master        Married  65073.0        0         0
# 663    663        1954  Graduation        Married  38998.0        1         1
# 816    816        1950  Graduation       Together  48070.0        0         1
# 841    841        1979  Graduation        Married  17688.0        1         0
# 927    927        1959  Graduation       Together  57957.0        0         1
# 941    941        1964  Graduation        Married  40800.0        1         2
# 1031  1031        1984         PhD         Single  39684.0        1         0
# 1090  1090        1978  Graduation         Single  38643.0        1         1
#
#      Dt_Customer  Recency  NumDealsPurchases  ...  AcceptedCmp5  AcceptedCmp1  \
# 448   20-03-2014       15                  3  ...             0             0
# ...

# %%
d_f1[(d_f1['Marital_Status_Group'] == 0)]
# Out:
# Empty DataFrame
# Columns: [id, Year_Birth, Education, Marital_Status, Income, Kidhome, Teenhome, Dt_Customer, Recency, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, AcceptedCmp3, AcceptedCmp4, AcceptedCmp5, AcceptedCmp1, AcceptedCmp2, Complain, Response, target, Dependents, Marital_Status_Group, TotalPurchases, TotalAcceptedCmp]
# Index: []
#
# [0 rows x 25 columns]

# %%
d_f1[['Income','TotalPurchases']].corr()
# Out:
#                   Income  TotalPurchases
# Income          1.000000        0.642499
# TotalPurchases  0.642499        1.000000

# %%
pear_r,pear_pval = stats.pearsonr(d_f1['Income'],d_f1['TotalPurchases'])
print(f'상관계수:{pear_r},유의확률:{pear_pval}')
# Out:
# 상관계수:0.6424985184230033,유의확률:8.710674531959914e-130

# %% [markdown]
# ### 상관분석을 위해서 Marital_Status_Group 변수를 더미변수화함.

# %%
d_f1['Marital_Status_Group'] = d_f1['Marital_Status_Group'].apply(lambda x : x.replace('Single','0'))
d_f1['Marital_Status_Group'] = d_f1['Marital_Status_Group'].apply(lambda x : x.replace('Together','1'))
d_f1['Marital_Status_Group'] = list(map(int,d_f1['Marital_Status_Group']))

# %%
d_f1['Marital_Status_Group'].unique()
# Out:
# array([1, 0])

# %%
d_f1[['Income','Marital_Status_Group']].corr()
# Out:
#                         Income  Marital_Status_Group
# Income                1.000000             -0.246517
# Marital_Status_Group -0.246517              1.000000

# %%
d_f1[['TotalPurchases','Marital_Status_Group']].corr()
# Out:
#                       TotalPurchases  Marital_Status_Group
# TotalPurchases              1.000000             -0.116389
# Marital_Status_Group       -0.116389              1.000000

# %%
d_f1[['target','Marital_Status_Group']].corr()
# Out:
#                         target  Marital_Status_Group
# target                1.000000             -0.284804
# Marital_Status_Group -0.284804              1.000000

# %%
d_f1[['TotalAcceptedCmp','Marital_Status_Group']].corr()
# Out:
#                       TotalAcceptedCmp  Marital_Status_Group
# TotalAcceptedCmp              1.000000             -0.204173
# Marital_Status_Group         -0.204173              1.000000

# %%
d_f1[['target','Income']].corr()
# Out:
#           target    Income
# target  1.000000  0.784704
# Income  0.784704  1.000000

# %%
pear_r,pear_pval = stats.pearsonr(d_f1['Marital_Status_Group'],d_f1['target'])
print(f'상관계수:{pear_r},유의확률:{pear_pval}')
# Out:
# 상관계수:-0.2848036755743836,유의확률:4.3865184116022715e-22

# %%
pear_r,pear_pval = stats.pearsonr(d_f1['Income'],d_f1['target'])
print(f'상관계수:{pear_r},유의확률:{pear_pval}')
# Out:
# 상관계수:0.7847036821740891,유의확률:1.5350032236771706e-231

# %%
plt.boxplot(x='Income',data=d_f1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7e555b970>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7e55821c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7e555b8e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7e55829d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7c3b082e0>],
#  'means': []}

# %%
print(d_f1.describe())
print(d_f1.describe(include = object))
# Out:
#                 id   Year_Birth         Income      Kidhome     Teenhome  \
# count  1106.000000  1106.000000    1106.000000  1106.000000  1106.000000
# mean    553.031646  1968.831826   52082.436709     0.429476     0.511754
# std     320.088082    11.842966   21322.919201     0.545653     0.551712
# min       0.000000  1940.000000    1730.000000     0.000000     0.000000
# 25%     276.250000  1959.000000   35723.500000     0.000000     0.000000
# 50%     552.500000  1970.000000   51609.500000     0.000000     0.000000
# 75%     829.750000  1977.000000   68343.000000     1.000000     1.000000
# max    1107.000000  1996.000000  162397.000000     2.000000     2.000000
#
#            Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  1106.000000        1106.000000      1106.000000          1106.000000
# mean     50.136528           2.341772         4.188969             2.694394
# std      29.063301           1.944201         2.810695             2.793124
# ...

# %% [markdown]
# ### 1사분위수까지 저소득층, 3사분위수부터 고소득층, 그외는 중위층으로 하여 Income_Group이라는 새 변수 생성

# %%
d_f1['Income_Group'] = d_f1['Income'] 
d_f1['Income_Group']
# Out:
# 0       46014.0
# 1       76624.0
# 2       75903.0
# 3       18393.0
# 4       64014.0
#          ...
# 1103    46097.0
# 1104    23477.0
# 1105    37368.0
# 1106    53034.0
# 1107    46610.0
# Name: Income_Group, Length: 1106, dtype: float64

# %%
d_f1.loc[d_f1.Income <=35860 , 'Income_Group'] = 'Lower_Income_group'

# %%
d_f1.loc[d_f1.Income >=68397 , 'Income_Group'] = 'Higher_Income_group'

# %%
d_f1.loc[(d_f1.Income >35860) & (d_f1.Income <68397) , 'Income_Group'] = 'Middle_Income_group'

# %%
d_f1
# Out:
#         id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0        0        1974      Master       Together  46014.0        1         1
# 1        1        1962  Graduation         Single  76624.0        0         1
# 2        2        1951  Graduation        Married  75903.0        0         1
# 3        3        1974       Basic        Married  18393.0        1         0
# 4        4        1946         PhD       Together  64014.0        2         1
# ...    ...         ...         ...            ...      ...      ...       ...
# 1103  1103        1956  Graduation       Together  46097.0        0         1
# 1104  1104        1986  Graduation        Married  23477.0        1         0
# 1105  1105        1975      Master        Married  37368.0        1         0
# 1106  1106        1974  Graduation       Divorced  53034.0        1         1
# 1107  1107        1952         PhD       Divorced  46610.0        0         2
#
# ...

# %% [markdown]
# ### 소득층 별 소비량 차이 많이남.

# %%
d__f4=d_f1[(d_f1['Income_Group'] == 'Lower_Income_group')]
print(d__f4.describe())
print(d__f4.describe(include = object))
# Out:
#                 id   Year_Birth        Income     Kidhome    Teenhome  \
# count   281.000000   281.000000    281.000000  281.000000  281.000000
# mean    554.964413  1974.466192  25581.868327    0.811388    0.256228
# std     334.150510    10.413578   7770.072399    0.510614    0.453367
# min       3.000000  1946.000000   1730.000000    0.000000    0.000000
# 25%     260.000000  1969.000000  21255.000000    1.000000    0.000000
# 50%     571.000000  1975.000000  26907.000000    1.000000    0.000000
# 75%     844.000000  1983.000000  31788.000000    1.000000    0.000000
# max    1104.000000  1996.000000  35860.000000    2.000000    2.000000
#
#           Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  281.000000         281.000000       281.000000           281.000000
# mean    49.021352           2.042705         1.964413             0.412811
# std     29.411239           1.629513         1.802423             0.579759
# ...

# %%
d__f5=d_f1[(d_f1['Income_Group'] == 'Middle_Income_group')]
print(d__f5.describe())
print(d__f5.describe(include = object))
# Out:
#                 id   Year_Birth        Income     Kidhome    Teenhome  \
# count   549.000000   549.000000    549.000000  549.000000  549.000000
# mean    549.681239  1966.659381  52002.770492    0.408015    0.750455
# std     312.946240    11.083073   9666.902709    0.537982    0.517596
# min       0.000000  1940.000000  35893.000000    0.000000    0.000000
# 25%     287.000000  1958.000000  43300.000000    0.000000    0.000000
# 50%     541.000000  1968.000000  51766.000000    0.000000    1.000000
# 75%     815.000000  1975.000000  60544.000000    1.000000    1.000000
# max    1107.000000  1992.000000  68352.000000    2.000000    2.000000
#
#           Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  549.000000         549.000000       549.000000           549.000000
# mean    50.227687           2.994536         4.632058             2.391621
# std     28.526097           2.142285         2.647708             2.272014
# ...

# %%
d__f6=d_f1[(d_f1['Income_Group'] == 'Higher_Income_group')]
print(d__f6.describe())
print(d__f6.describe(include = object))
# Out:
#                 id   Year_Birth         Income     Kidhome    Teenhome  \
# count   276.000000   276.000000     276.000000  276.000000  276.000000
# mean    557.728261  1967.416667   79221.554348    0.083333    0.297101
# std     320.616398    12.826263   11064.303348    0.289723    0.503218
# min       1.000000  1941.000000   68397.000000    0.000000    0.000000
# 25%     279.500000  1957.000000   72182.250000    0.000000    0.000000
# 50%     570.500000  1968.000000   77699.000000    0.000000    0.000000
# 75%     828.750000  1977.000000   82394.750000    0.000000    1.000000
# max    1102.000000  1995.000000  162397.000000    2.000000    2.000000
#
#           Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  276.000000         276.000000       276.000000           276.000000
# mean    51.090580           1.347826         5.572464             5.619565
# std     29.825354           1.185685         2.663935             2.574740
# ...

# %% [markdown]
# ### 소득층별 평균 소비량 시각화

# %%
x = ['Lower_Income_group','Middle_Income_group','Higher_Income_group']
y = [74,523,1361,]
width = 1/1.5 

import matplotlib.pyplot as plt

plt.bar(x,y)

for i, v in enumerate(x):
    plt.text(v, y[i], y[i],               
             fontsize = 9, 
             color='blue',
             horizontalalignment='center',  
             verticalalignment='bottom')
     
plt.show()

# %%
plt.boxplot(x='Year_Birth',data=d_f1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7c3dad850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7e54fcac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7c3dadaf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7e54fc730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7e54fcd30>],
#  'means': []}

# %%
d_f1['Year_Birth_Group'] = d_f1['Year_Birth'] 
d_f1['Year_Birth_Group']
# Out:
# 0       1974
# 1       1962
# 2       1951
# 3       1974
# 4       1946
#         ...
# 1103    1956
# 1104    1986
# 1105    1975
# 1106    1974
# 1107    1952
# Name: Year_Birth_Group, Length: 1106, dtype: int64

# %%
d___f1=d_f1[(d_f1['Year_Birth'] <1959 )]
print(d___f1.describe())
print(d___f1.describe(include = object))
# Out:
#                 id   Year_Birth         Income     Kidhome    Teenhome  \
# count   260.000000   260.000000     260.000000  260.000000  260.000000
# mean    555.553846  1952.592308   58433.350000    0.223077    0.692308
# std     324.430801     4.087265   18002.511671    0.469377    0.567405
# min       2.000000  1940.000000    6835.000000    0.000000    0.000000
# 25%     279.000000  1950.000000   46689.250000    0.000000    0.000000
# 50%     542.000000  1953.000000   58544.500000    0.000000    1.000000
# 75%     822.000000  1956.000000   71786.000000    0.000000    1.000000
# max    1107.000000  1958.000000  113734.000000    2.000000    2.000000
#
#           Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  260.000000         260.000000       260.000000           260.000000
# mean    48.384615           2.388462         4.761538             3.492308
# std     29.232231           2.005557         2.881987             2.963735
# ...

# %%
d___f2=d_f1[(d_f1['Year_Birth'] >1977 )]
print(d___f2.describe())
print(d___f2.describe(include = object))
# Out:
#                 id   Year_Birth         Income     Kidhome    Teenhome  \
# count   276.000000   276.000000     276.000000  276.000000  276.000000
# mean    573.931159  1983.746377   46271.239130    0.586957    0.141304
# std     316.638042     4.386859   22805.581169    0.535683    0.359237
# min       7.000000  1978.000000    7500.000000    0.000000    0.000000
# 25%     309.750000  1980.000000   28287.250000    0.000000    0.000000
# 50%     578.500000  1983.000000   40570.500000    1.000000    0.000000
# 75%     856.750000  1987.000000   67449.000000    1.000000    0.000000
# max    1104.000000  1996.000000  101970.000000    2.000000    2.000000
#
#           Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  276.000000         276.000000       276.000000           276.000000
# mean    49.923913           1.818841         3.528986             2.192029
# std     29.450198           1.376348         2.608216             2.691956
# ...

# %%
d___f3=d_f1[(d_f1['Year_Birth'] >1960) & (d_f1['Year_Birth'] <1977) ]
print(d___f3.describe())
print(d___f3.describe(include = object))
# Out:
#                 id   Year_Birth         Income     Kidhome    Teenhome  \
# count   504.000000   504.000000     504.000000  504.000000  504.000000
# mean    536.900794  1969.434524   51567.710317    0.466270    0.603175
# std     320.067429     4.439082   21210.785276    0.555877    0.543596
# min       0.000000  1961.000000    1730.000000    0.000000    0.000000
# 25%     259.500000  1966.000000   36411.500000    0.000000    0.000000
# 50%     537.500000  1970.000000   51683.500000    0.000000    1.000000
# 75%     810.500000  1973.000000   66482.750000    1.000000    1.000000
# max    1106.000000  1976.000000  162397.000000    2.000000    2.000000
#
#           Recency  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# count  504.000000         504.000000       504.000000           504.000000
# mean    51.077381           2.583333         4.242063             2.501984
# std     28.820552           2.135797         2.803175             2.647628
# ...

# %%
plt.boxplot(x='NumWebPurchases',data=d_f1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7c3c69550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7c3c69cd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7b1b61a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7e456feb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7d1153f10>],
#  'means': []}

# %% [markdown]
# ### NumWebPurchases 이상치 제거

# %%
d_f1[(d_f1['NumWebPurchases']>20)]
# Out:
#       id  Year_Birth Education Marital_Status    Income  Kidhome  Teenhome  \
# 617  617        1966       PhD         Single    7144.0        0         2
# 892  892        1945       PhD         Single  113734.0        0         0
#
#     Dt_Customer  Recency  NumDealsPurchases  ...  AcceptedCmp2  Complain  \
# 617  07-12-2013       92                  0  ...             0         0
# 892  28-05-2014        9                  0  ...             0         0
#
#      Response  target  Dependents  Marital_Status_Group  TotalPurchases  \
# 617         0     416           2                     1              48
# 892         0     277           0                     0              54
#
#      TotalAcceptedCmp         Income_Group  Year_Birth_Group
# 617                 0   Lower_Income_group              1966
# 892                 0  Higher_Income_group              1945
#
# [2 rows x 27 columns]

# %%
d______f3=d_f1.drop([617,892],axis=0)
d______f3
# Out:
#         id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0        0        1974      Master       Together  46014.0        1         1
# 1        1        1962  Graduation         Single  76624.0        0         1
# 2        2        1951  Graduation        Married  75903.0        0         1
# 3        3        1974       Basic        Married  18393.0        1         0
# 4        4        1946         PhD       Together  64014.0        2         1
# ...    ...         ...         ...            ...      ...      ...       ...
# 1103  1103        1956  Graduation       Together  46097.0        0         1
# 1104  1104        1986  Graduation        Married  23477.0        1         0
# 1105  1105        1975      Master        Married  37368.0        1         0
# 1106  1106        1974  Graduation       Divorced  53034.0        1         1
# 1107  1107        1952         PhD       Divorced  46610.0        0         2
#
# ...

# %%
plt.boxplot(x='NumWebPurchases',data=d______f3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb7e48f07f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb7e48f0670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb7e48f0340>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb7d149bc70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb7d156a340>],
#  'means': []}

# %%
c = d______f3[['NumWebPurchases', 'Education']]
d = c.groupby('Education').aggregate([min, np.median, max,np.mean])
d
# Out:
#            NumWebPurchases
#                        min median max      mean
# Education
# 2n Cycle                 0    4.0  11  4.275862
# Basic                    0    2.0   4  1.772727
# Graduation               0    3.0  11  4.038596
# Master                   0    4.0  10  4.115607
# PhD                      0    4.0  11  4.595238

# %%
d_f1[(d_f1['Education'] == 'Basic')]
# Out:
#         id  Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# 3        3        1974     Basic        Married  18393.0        1         0
# 127    127        1958     Basic         Single  15056.0        1         1
# 139    139        1987     Basic         Single  15038.0        1         0
# 173    173        1973     Basic       Together   9722.0        1         0
# 208    208        1952     Basic       Together  13084.0        0         0
# 265    265        1992     Basic         Single  15253.0        1         0
# 314    314        1969     Basic       Together  22390.0        0         0
# 329    329        1976     Basic        Married   7500.0        0         0
# 332    332        1986     Basic        Married  20425.0        1         0
# 415    415        1978     Basic       Together  24882.0        1         0
# 423    423        1979     Basic       Together  23724.0        1         0
# ...

# %%
from sklearn.linear_model import LinearRegression 
lr = LinearRegression()

# %%
from statsmodels.formula.api import ols

# %%
res = ols('target ~ NumWebPurchases', data=d_f1).fit()

# %%
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.297
# Method:                 Least Squares   F-statistic:                     467.3
# Date:                Wed, 11 May 2022   Prob (F-statistic):           1.06e-86
# Time:                        14:23:06   Log-Likelihood:                -8455.4
# No. Observations:                1106   AIC:                         1.691e+04
# Df Residuals:                    1104   BIC:                         1.692e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
from scipy.stats import f_oneway

xx=d_f1['NumWebPurchases']
yy=d_f1['target']

f_oneway(xx,yy)
# Out:
# F_onewayResult(statistic=1144.1560609346993, pvalue=1.7653039977436256e-202)

# %%
xx1=d_f1['NumStorePurchases']
f_oneway(xx1,yy)
# Out:
# F_onewayResult(statistic=1137.7326553672563, pvalue=1.470728834051969e-201)

# %%
xx2=d_f1['TotalPurchases']
f_oneway(xx2,yy)
# Out:
# F_onewayResult(statistic=1088.151087070016, pvalue=2.160707710042827e-194)

# %%
xx4=d_f1['NumCatalogPurchases']
f_oneway(xx4,yy)
# Out:
# F_onewayResult(statistic=1149.7335430784926, pvalue=2.8105507396186734e-203)

# %%
from statsmodels.genmod.generalized_linear_model import GLM
from statsmodels.genmod.families import Poisson

# %%
xx3=d_f1['NumStorePurchases']
f_oneway(xx3,yy)
# Out:
# F_onewayResult(statistic=1137.7326553672563, pvalue=1.470728834051969e-201)

# %%
y=d_f1['target']
x=d_f1['NumWebPurchases']

model = GLM(y,x,family=Poisson())
results=model.fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                 target   No. Observations:                 1106
# Model:                            GLM   Df Residuals:                     1105
# Model Family:                 Poisson   Df Model:                            0
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -2.5217e+06
# Date:                Wed, 11 May 2022   Deviance:                   5.0351e+06
# Time:                        14:23:08   Pearson chi2:                 1.03e+08
# No. Iterations:                    22
# Covariance Type:            nonrobust
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
print(pd.pivot_table(d_f1,
    index=['Dependents'],
    values=['NumWebPurchases'],
    aggfunc=['count']))
# Out:
#                      count
#            NumWebPurchases
# Dependents
# 0                      316
# 1                      570
# 2                      189
# 3                       31

# %%
d_f1[['TotalAcceptedCmp','target','Response']].corr()
# Out:
#                   TotalAcceptedCmp    target  Response
# TotalAcceptedCmp          1.000000  0.420732  0.763979
# target                    0.420732  1.000000  0.242296
# Response                  0.763979  0.242296  1.000000

# %%
d_f1[(d_f1['AcceptedCmp2']==1)]
# Out:
#         id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 35      35        1983         PhD       Together  70123.0        0         0
# 94      94        1958         PhD       Together  84460.0        0         0
# 150    150        1969         PhD        Married  55212.0        0         1
# 237    237        1969         PhD        Married  55212.0        0         1
# 303    303        1964         PhD       Divorced  64140.0        0         2
# 407    407        1959  Graduation       Together  87771.0        0         1
# 600    600        1968  Graduation         Single  57107.0        0         1
# 641    641        1977         PhD        Married  61996.0        0         1
# 693    693        1968  Graduation       Together  56534.0        0         1
# 712    712        1954  Graduation       Divorced  85683.0        0         0
# 721    721        1990      Master         Single  91172.0        0         0
# ...
